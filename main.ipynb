# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
wine = pd.read_csv('./WineQT.csv')
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
wine.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# Id                        int64
# dtype: object

# %%
wine.nunique()
# Out:
# fixed acidity             91
# volatile acidity         135
# citric acid               77
# residual sugar            80
# chlorides                131
# free sulfur dioxide       53
# total sulfur dioxide     138
# density                  388
# pH                        87
# sulphates                 89
# alcohol                   61
# quality                    6
# Id                      1143
# dtype: int64

# %%
wine.shape
# Out:
# (1143, 13)

# %%
wine.drop(['Id'],axis=1,inplace=True)

# %%
wine.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
wine.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.250728     0.673157
# volatile acidity          -0.250728          1.000000    -0.544187
# citric acid                0.673157         -0.544187     1.000000
# residual sugar             0.171831         -0.005751     0.175815
# chlorides                  0.107889          0.056336     0.245312
# free sulfur dioxide       -0.164831         -0.001962    -0.057589
# total sulfur dioxide      -0.110628          0.077748     0.036871
# density                    0.681501          0.016512     0.375243
# pH                        -0.685163          0.221492    -0.546339
# sulphates                  0.174592         -0.276079     0.331232
# alcohol                   -0.075055         -0.203909     0.106250
# quality                    0.121970         -0.407394     0.240821
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
wine.corr()['quality'].sort_values()
# Out:
# volatile acidity       -0.407394
# total sulfur dioxide   -0.183339
# density                -0.175208
# chlorides              -0.124085
# free sulfur dioxide    -0.063260
# pH                     -0.052453
# residual sugar          0.022002
# fixed acidity           0.121970
# citric acid             0.240821
# sulphates               0.257710
# alcohol                 0.484866
# quality                 1.000000
# Name: quality, dtype: float64

# %%
sns.countplot(x=wine['alcohol'])
# Out:
# <Axes: xlabel='alcohol', ylabel='count'>

# %%
sns.countplot(x=wine['pH'])
# Out:
# <Axes: xlabel='pH', ylabel='count'>

# %%
sns.countplot(x=wine['sulphates'])
# Out:
# <Axes: xlabel='sulphates', ylabel='count'>

# %%
sns.countplot(x=wine['chlorides'])
# Out:
# <Axes: xlabel='chlorides', ylabel='count'>

# %%
sns.countplot(x=wine['density'])
# Out:
# <Axes: xlabel='density', ylabel='count'>

# %%
sns.distplot(x=wine['alcohol'])
# Out:
# <Axes: ylabel='Density'>

# %%
wine.hist(bins=50,figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'fixed acidity'}>,
#         <Axes: title={'center': 'volatile acidity'}>,
#         <Axes: title={'center': 'citric acid'}>],
#        [<Axes: title={'center': 'residual sugar'}>,
#         <Axes: title={'center': 'chlorides'}>,
#         <Axes: title={'center': 'free sulfur dioxide'}>],
#        [<Axes: title={'center': 'total sulfur dioxide'}>,
#         <Axes: title={'center': 'density'}>,
#         <Axes: title={'center': 'pH'}>],
#        [<Axes: title={'center': 'sulphates'}>,
#         <Axes: title={'center': 'alcohol'}>,
#         <Axes: title={'center': 'quality'}>]], dtype=object)

# %%
wine['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
wine['good quality'] = [ 1 if x >=7 else 0 for x in wine['quality']]
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  good quality
# 0      9.4        5             0
# ...

# %%
wine['good quality'].value_counts()
# Out:
# good quality
# 0    984
# 1    159
# Name: count, dtype: int64

# %%
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  good quality
# 0      9.4        5             0
# ...

# %%
corr_matrix = wine.corr()
corr_matrix['good quality'].sort_values()
# Out:
# volatile acidity       -0.304523
# density                -0.148670
# total sulfur dioxide   -0.113373
# chlorides              -0.103985
# pH                     -0.073318
# free sulfur dioxide    -0.055977
# residual sugar          0.064145
# fixed acidity           0.123212
# sulphates               0.208020
# citric acid             0.251146
# alcohol                 0.403676
# quality                 0.720433
# good quality            1.000000
# Name: good quality, dtype: float64

# %%
X = wine.drop(['quality','good quality'],axis=1)
Y = wine['good quality']

# %% [markdown]
# Data Spliting

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.3,random_state=7)

# %% [markdown]
# Using Decision tree:

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier(max_depth=6,criterion='entropy',random_state=7)
model = dtc.fit(x_train,y_train)
pred = model.predict(x_test)

from sklearn.metrics import accuracy_score
print("Accuaracy Score : " ,accuracy_score(pred,y_test)*100 )
# Out:
# Accuaracy Score :  86.0058309037901

# %% [markdown]
# Using Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lg = LogisticRegression()
model = lg.fit(x_train,y_train)
pred = model.predict(x_test)

print("Accuaracy Score : " ,accuracy_score(pred,y_test)*100 )
# Out:
# Accuaracy Score :  87.75510204081633

# %% [markdown]
# Using RandomForest :

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=7,max_depth=6,criterion='entropy',random_state=42)
model = rfc.fit(x_train,y_train)
pred = model.predict(x_test)

print("Accuaracy Score : " ,accuracy_score(pred,y_test)*100 )
# Out:
# Accuaracy Score :  90.37900874635568
